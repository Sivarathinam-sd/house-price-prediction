# %%
import pandas as pd
df1 = pd.read_csv('../../datasets/cleaned_delhi_data.csv')
df2 = pd.read_csv('../../datasets/cleaned_mumbai_data.csv')
df3 = pd.read_csv('../../datasets/cleaned_pune_data.csv')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   numRooms                  5000 non-null   int64
#  1   house_configuration       5000 non-null   str
#  2   cleaned_house_type        5000 non-null   str
#  3   location                  5000 non-null   str
#  4   city                      5000 non-null   str
#  5   latitude                  5000 non-null   float64
#  6   longitude                 5000 non-null   float64
#  7   currency                  5000 non-null   str
#  8   numBathrooms              5000 non-null   float64
#  9   numBalconies              5000 non-null   float64
#  10  isNegotiable              5000 non-null   str
#  11  Status                    5000 non-null   str
#  12  converted_house_size      5000 non-null   float64
#  13  cleaned_security_deposit  5000 non-null   float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   numRooms                  5000 non-null   int64
#  1   house_configuration       5000 non-null   str
#  2   cleaned_house_type        5000 non-null   str
#  3   location                  5000 non-null   str
#  4   city                      5000 non-null   str
#  5   latitude                  5000 non-null   float64
#  6   longitude                 5000 non-null   float64
#  7   currency                  5000 non-null   str
#  8   numBathrooms              5000 non-null   float64
#  9   numBalconies              5000 non-null   float64
#  10  isNegotiable              5000 non-null   str
#  11  Status                    5000 non-null   str
#  12  converted_house_size      5000 non-null   float64
#  13  cleaned_security_deposit  5000 non-null   float64
# ...

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3910 entries, 0 to 3909
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   numRooms                  3910 non-null   int64
#  1   house_configuration       3910 non-null   str
#  2   cleaned_house_type        3910 non-null   str
#  3   location                  3910 non-null   str
#  4   city                      3910 non-null   str
#  5   latitude                  3910 non-null   float64
#  6   longitude                 3910 non-null   float64
#  7   currency                  3910 non-null   str
#  8   numBathrooms              3910 non-null   float64
#  9   numBalconies              3910 non-null   float64
#  10  isNegotiable              3910 non-null   str
#  11  Status                    3910 non-null   str
#  12  converted_house_size      3910 non-null   float64
#  13  cleaned_security_deposit  3910 non-null   float64
# ...

# %%
combined_housing_data = pd.concat([df1, df2, df3])
combined_housing_data
# Out:
#       numRooms house_configuration cleaned_house_type           location  \
# 0            1                  RK   Studio Apartment            Kalkaji
# 1            1                  RK   Studio Apartment  Mansarover Garden
# 2            2                 BHK  Independent Floor        Uttam Nagar
# 3            3                 BHK  Independent House         Model Town
# 4            2                 BHK          Apartment   Sector 13 Rohini
# ...        ...                 ...                ...                ...
# 3905         1                 BHK          Apartment              Wakad
# 3906         2                 BHK          Apartment    Pimple Saudagar
# 3907         1                 BHK          Apartment    Pimple Saudagar
# 3908         2                 BHK          Apartment    Pimple Saudagar
# 3909         2                 BHK          Apartment           Rahatani
#
#        city   latitude  longitude currency  numBathrooms  numBalconies  \
# ...

# %%
combined_housing_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 13910 entries, 0 to 3909
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   numRooms                  13910 non-null  int64
#  1   house_configuration       13910 non-null  str
#  2   cleaned_house_type        13910 non-null  str
#  3   location                  13910 non-null  str
#  4   city                      13910 non-null  str
#  5   latitude                  13910 non-null  float64
#  6   longitude                 13910 non-null  float64
#  7   currency                  13910 non-null  str
#  8   numBathrooms              13910 non-null  float64
#  9   numBalconies              13910 non-null  float64
#  10  isNegotiable              13910 non-null  str
#  11  Status                    13910 non-null  str
#  12  converted_house_size      13910 non-null  float64
#  13  cleaned_security_deposit  13910 non-null  float64
# ...

# %%
combined_housing_data['numRooms'].unique()
# Out:
# array([ 1,  2,  3,  4,  8,  6,  5,  7, 10,  9, 12])
